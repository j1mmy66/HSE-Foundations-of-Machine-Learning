# %% [markdown]
# <a href="https://colab.research.google.com/github/j1mmy66/HSE-Foundations-of-Machine-Learning/blob/main/hw02_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Описание данных
#
# В папке Dat (https://github.com/hse-ds/iad-intro-ds/blob/master/2023/homeworks/Data.zip) находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
students_info = pd.read_csv("Students_info_0.csv")
for i in range(1, 10):
  students_info = pd.concat([students_info,pd.read_csv(f'Students_info_{i}.csv')])
students_marks = pd.read_csv("Students_marks_0.csv")
for i in range(1, 10):
  students_marks = pd.concat([students_marks, pd.read_csv(f'Students_marks_{i}.csv')])
df = pd.merge(students_info, students_marks, on = 'index', how = 'left')
df.sample(n = 10)
# Out:
#      index  gender race/ethnicity parental level of education         lunch  \
# 645    645  female        group B           bachelor's degree      standard
# 417    417    male        group C          associate's degree      standard
# 81      81    male        group B                 high school  free/reduced
# 728    728  female        group D                 high school  free/reduced
# 937    937  female        group E                 high school  free/reduced
# 533    533  female        group E          associate's degree      standard
# 970    970  female        group D           bachelor's degree      standard
# 618    618    male        group D             master's degree      standard
# 425    425  female        group C                some college  free/reduced
# 194    194  female        group C             master's degree      standard
#
#     test preparation course    group  math score  reading score  writing score
# ...

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
df.drop('index', axis = 1)
df.head(10)
# Out:
#    index  gender race/ethnicity parental level of education         lunch  \
# 0      0  female        group B           bachelor's degree      standard
# 1      1  female        group C                some college      standard
# 2      2  female        group B             master's degree      standard
# 3      3    male        group A          associate's degree  free/reduced
# 4      4    male        group C                some college      standard
# 5      5  female        group B          associate's degree      standard
# 6      6  female        group B                some college      standard
# 7      7    male        group B                some college  free/reduced
# 8      8    male        group D                 high school  free/reduced
# 9      9  female        group B                 high school  free/reduced
#
#   test preparation course   group  math score  reading score  writing score
# 0                    none  group1          72             72             74
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
df.describe()
# Out:
#              index  math score  reading score  writing score
# count  1000.000000  1000.00000    1000.000000    1000.000000
# mean    499.500000    66.08900      69.169000      68.054000
# std     288.819436    15.16308      14.600192      15.195657
# min       0.000000     0.00000      17.000000      10.000000
# 25%     249.750000    57.00000      59.000000      57.750000
# 50%     499.500000    66.00000      70.000000      69.000000
# 75%     749.250000    77.00000      79.000000      79.000000
# max     999.000000   100.00000     100.000000     100.000000

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
df.isna().sum()
# Out:
# index                          0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# group                          0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
print(df['math score'].mean())
print(df['writing score'].mean())
print(df['reading score'].mean())
# Out:
# 66.089
# 68.054
# 69.169

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
print(df.groupby('test preparation course')['math score'].mean())
print(df.groupby('test preparation course')['reading score'].mean())
print(df.groupby('test preparation course')['writing score'].mean())
# Out:
# test preparation course
# completed    69.695531
# none         64.077882
# Name: math score, dtype: float64
# test preparation course
# completed    73.893855
# none         66.534268
# Name: reading score, dtype: float64
# test preparation course
# completed    74.418994
# none         64.504673
# Name: writing score, dtype: float64

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
df.lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df.rename(columns={"parental level of education": "education", "test preparation course": "test preparation"}, inplace=True)
df.head()
# Out:
#    index  gender race/ethnicity           education         lunch  \
# 0      0  female        group B   bachelor's degree      standard
# 1      1  female        group C        some college      standard
# 2      2  female        group B     master's degree      standard
# 3      3    male        group A  associate's degree  free/reduced
# 4      4    male        group C        some college      standard
#
#   test preparation   group  math score  reading score  writing score
# 0             none  group1          72             72             74
# 1        completed  group1          69             90             88
# 2             none  group1          90             95             93
# 3             none  group1          47             57             44
# 4             none  group1          76             78             75

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
print("доля студентов сдала экзамен по математике")
print((df['math score'] > passmark).value_counts(True)[0])
print("доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике")
print(((df['math score'] > passmark) & (df['test preparation'] == "completed")).value_counts()[1] / (df['test preparation'] == "completed").value_counts()[1])
print("доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике")
print(((df['math score'] < passmark) & (df['test preparation'] == "none") & (df['gender'] == "female")).value_counts()[1]/((df['test preparation'] == "none") & (df['gender'] == "female")).value_counts()[1])
# Out:
# доля студентов сдала экзамен по математике
# 0.85
# доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике
# 0.9078212290502793
# доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике
# 0.20958083832335328

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
# %%time
print(df.groupby(df['race/ethnicity'])['reading score'].mean())
print(df.groupby(df['education'])['writing score'].min())
# Out:
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64
# CPU times: user 6.12 ms, sys: 842 µs, total: 6.96 ms
# Wall time: 7.92 ms

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
# %%time

print('For every race/ethnicity reading score: ')
for group in df['race/ethnicity'].unique():
  print('Group: {}, mean = {}'.format(group, df[df['race/ethnicity'] == group]['reading score'].mean()))

print()

print('For every level of education writing score: ')
for group in df['education'].unique():
  print('Group: {}, min = {}'.format(group, df[df['education'] == group]['writing score'].min()))

print()
# Out:
# For every race/ethnicity reading score:
# Group: group B, mean = 67.35263157894737
# Group: group C, mean = 69.10344827586206
# Group: group A, mean = 64.67415730337079
# Group: group D, mean = 70.03053435114504
# Group: group E, mean = 73.02857142857142
#
# For every level of education writing score:
# Group: bachelor's degree, min = 38
# Group: some college, min = 19
# Group: master's degree, min = 46
# Group: associate's degree, min = 35
# Group: high school, min = 15
# Group: some high school, min = 10
#
# CPU times: user 21.5 ms, sys: 1.89 ms, total: 23.4 ms
# Wall time: 23.2 ms

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
print(df.groupby([df['gender'], df['education']])['math score'].mean())
print()
print(df.groupby([df['gender'], df['education']])['writing score'].mean())
print()
print(df.groupby([df['gender'], df['education']])['reading score'].mean())
# Out:
# gender  education
# female  associate's degree    65.250000
#         bachelor's degree     68.349206
#         high school           59.351064
#         master's degree       66.500000
#         some college          65.406780
#         some high school      59.296703
# male    associate's degree    70.764151
#         bachelor's degree     70.581818
#         high school           64.705882
#         master's degree       74.826087
#         some college          69.009259
#         some high school      67.840909
# Name: math score, dtype: float64
#
# gender  education
# female  associate's degree    74.000000
#         bachelor's degree     78.380952
#         high school           66.691489
#         master's degree       77.638889
#         some college          74.050847
#         some high school      68.285714
# male    associate's degree    65.405660
#         bachelor's degree     67.654545
#         high school           58.539216
# ...

# %%
pd.pivot_table(df,index=['gender','education'],values=['math score', 'writing score', 'reading score'], aggfunc=np.mean)
# Out:
#                            math score  reading score  writing score
# gender education
# female associate's degree   65.250000      74.120690      74.000000
#        bachelor's degree    68.349206      77.285714      78.380952
#        high school          59.351064      68.202128      66.691489
#        master's degree      66.500000      76.805556      77.638889
#        some college         65.406780      73.550847      74.050847
#        some high school     59.296703      69.109890      68.285714
# male   associate's degree   70.764151      67.433962      65.405660
#        bachelor's degree    70.581818      68.090909      67.654545
#        high school          64.705882      61.480392      58.539216
#        master's degree      74.826087      73.130435      72.608696
#        some college         69.009259      64.990741      63.148148
#        some high school     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
df['Math_PassStatus'] = df['math score'].apply(lambda x: 'F' if x < passmark else 'T')
df['Reading_PassStatus'] = df['reading score'].apply(lambda x: 'F' if x < passmark else 'T')
df['Writing_PassStatus'] = df['writing score'].apply(lambda x: 'F' if x < passmark else 'T')
df.head()
# Out:
#    index  gender race/ethnicity           education         lunch  \
# 0      0  female        group B   bachelor's degree      standard
# 1      1  female        group C        some college      standard
# 2      2  female        group B     master's degree      standard
# 3      3    male        group A  associate's degree  free/reduced
# 4      4    male        group C        some college      standard
#
#   test preparation   group  math score  reading score  writing score  \
# 0             none  group1          72             72             74
# 1        completed  group1          69             90             88
# 2             none  group1          90             95             93
# 3             none  group1          47             57             44
# 4             none  group1          76             78             75
#
#   Math_PassStatus Reading_PassStatus Writing_PassStatus
# 0               T                  T                  T
# ...

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
df['OverAll_PassStatus'] = df.apply(lambda row: "T" if (row['Math_PassStatus'] == "T" and row['Reading_PassStatus'] == "T" and row['Writing_PassStatus'] == "T") else "F", axis=1)

df.head()
# Out:
#    index  gender race/ethnicity           education         lunch  \
# 0      0  female        group B   bachelor's degree      standard
# 1      1  female        group C        some college      standard
# 2      2  female        group B     master's degree      standard
# 3      3    male        group A  associate's degree  free/reduced
# 4      4    male        group C        some college      standard
#
#   test preparation   group  math score  reading score  writing score  \
# 0             none  group1          72             72             74
# 1        completed  group1          69             90             88
# 2             none  group1          90             95             93
# 3             none  group1          47             57             44
# 4             none  group1          76             78             75
#
#   Math_PassStatus Reading_PassStatus Writing_PassStatus OverAll_PassStatus
# 0               T                  T                  T                  T
# ...

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
def GetGrade(mark: int):
    if (90 <= mark and mark <= 100):
      return 'A'
    if (80 <= mark and mark < 90):
      return 'B'
    if (70 <= mark and mark < 80):
      return 'C'
    if (60 <= mark and mark < 70):
      return 'D'
    if (50 <= mark and mark < 60):
      return 'E'
    return 'F'

def helper(row):
  return GetGrade((row['math score'] + row['reading score'] + row['writing score']) / 3)

df['Grade'] = df.apply(helper, axis=1)
df.sample(n=15)
# Out:
#      index  gender race/ethnicity           education         lunch  \
# 741    741  female        group A  associate's degree  free/reduced
# 725    725    male        group E        some college      standard
# 868    868    male        group E  associate's degree  free/reduced
# 345    345  female        group C         high school      standard
# 462    462  female        group E        some college      standard
# 656    656    male        group C  associate's degree  free/reduced
# 600    600  female        group D     master's degree      standard
# 424    424    male        group B        some college  free/reduced
# 2        2  female        group B     master's degree      standard
# 790    790  female        group B         high school      standard
# 520    520    male        group D        some college      standard
# 963    963  female        group C    some high school  free/reduced
# 344    344    male        group D        some college      standard
# ...
